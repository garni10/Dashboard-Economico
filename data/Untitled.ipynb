# %%
with open("detalle_binance3.csv", "r", encoding="utf-8") as f:
    for i in range(10):
        print(f.readline())
# Out:
# ﻿Precio;Vendedor;Limite_min;Limite_max;Disponible;Timestamp;Tipo
#
# 12.81;MessidelUSDT;55;138390;95.24;11/9/2025 18:00;BUY
#
# 12.88;Criptoren-10K;55;138390;334.47;11/9/2025 18:00;BUY
#
# 12.88;Schutmaat;1000;13000;628.18;11/9/2025 18:00;BUY
#
# 12.89;Venom_Sjzb;500;200000;507.55;11/9/2025 18:00;BUY
#
# 12.89;Gypsi12;2500;30000;953.92;11/9/2025 18:00;BUY
#
# 12.9;RameCoin;100;3000;123.47;11/9/2025 18:00;BUY
#
# 12.9;Jhonof7;3000;207585;5179.2;11/9/2025 18:00;BUY
#
# 12.9;Romero Fx;5000;200000;3000;11/9/2025 18:00;BUY
#
# 12.9;Leooocripto;55;138390;500;11/9/2025 18:00;BUY

# %%
import pandas as pd

df = pd.read_csv(
    "detalle_binance3.csv",
    sep=";",
    engine="python"
)

print(df.tail())
print(df.shape)
# Out:
#         Precio           Vendedor  Limite_min  Limite_max  Disponible  \
# 293884    6.84             koko92         100       13000      5000.0
# 293885    6.60       P2P-9eb146ba          55        1000       100.0
# 293886    6.50            Foradex         150         155       100.0
# 293887    5.20  CR7-Crypto-Trader         150      207585      1452.0
# 293888    5.18             BolCom          55        5000      5000.0
#
#               Timestamp  Tipo
# 293884  24/6/2026 09:00  SELL
# 293885  24/6/2026 09:00  SELL
# 293886  24/6/2026 09:00  SELL
# 293887  24/6/2026 09:00  SELL
# 293888  24/6/2026 09:00  SELL
# (293889, 7)

# %%
print(df["Timestamp"].isna().sum())
# Out:
# 0

# %%
print(df_binance.dtypes)
print(df_binance["Timestamp"].head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(df_binance.dtypes)
#       2 print(df_binance["Timestamp"].head(10))
#
# NameError: name 'df_binance' is not defined
