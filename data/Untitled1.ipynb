# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\sergio.garnica\hipermaxi_detallado_suc.csv"
)

print(df["Fecha"].min())
print(df["Fecha"].max())
print(df["Fecha"].nunique())
# Out:
# 2026-05-27
# 2026-06-10
# 15

# %%
df2 = pd.read_csv(
    r"C:\Users\sergio.garnica\Dashboard-Economico\data\hipermaxi_detallado_suc.csv"
)

print(df2["Fecha"].min())
print(df2["Fecha"].max())
print(df2["Fecha"].nunique())
# Out:
# 2026-06-12
# 2026-06-12
# 1
